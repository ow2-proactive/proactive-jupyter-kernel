# %%
#%connect(login=MYLOGIN,password=MYPASSWORD)

# %%
#%task(name=t1,generic_info=[(key1,value1),(key2,value2)],language=Python)
print('Hello world from python task')
result = "test"
# Out:
# Creating a proactive Python task...
# Adding a selection script to the proactive task...
# Task 't1' created.
# Adding generic information...
# Done.

# %%
#%pre_script(name=t1,language=Linux_Bash)
echo "This is a pre-script";
# Out:
# Adding a pre-script to the proactive task...
# Pre-script added to 't1'.

# %%
#%post_script(name=t1,language=Linux_Bash)
echo "This is a post-script";
# Out:
# Adding a post-script to the proactive task...
# Post-script added to 't1'.

# %%
#%  task(name=t2,dep=[t1,dw],language=Jython)
print('Hello world')
print('From Jupyter Kernel!')
result = 123
# Out:
# Creating a proactive Jython task...
# Adding a selection script to the proactive task...
# Task 't2' created.
# Dependence 't1'==>'t2' added.
# WARNING: Task 'dw' does not exist, dependence ignored.
# Done.

# %%
#%  task(name=t3,dep=[t1])
print('Another task')
result = 123
# Out:
# Creating a proactive 'Python' task...
# Adding a selection script to the proactive task...
# Task 't3' created.
# Dependence 't1'==>'t3' added.
# Done.

# %%
#%  task(name=t4,dep=[t2,t1,t66])
print('One last task')
result = 123
# Out:
# WARNING: Task 't4' exists already...
# Changing script language to 'Python' ...
# Dependence 't2'==>'t4' added.
# Dependence 't1'==>'t4' added.
# WARNING: Task 't66' does not exist, dependence ignored.
# Done.

# %%
#%draw_job()
# Out:
# Creating the job workflow...
# Workflow created.
# Plotting...

# %%
#%job(name=CompleteTestFromKernel)
# Out:
# Job renamed to 'CompleteTestFromKernel'.

# %%
#%submit_job()
# Out:
# Submitting the job to the proactive scheduler...
# job_id: 28

# %%
#%get_result(id=28)
# Out:
# Getting job 28 output...
# Result:
# 123
# test
# 123
# 123
